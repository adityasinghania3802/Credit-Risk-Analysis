# %% [markdown]
# # Dataset: [Credit Risk Analysis](https://www.kaggle.com/datasets/rameshmehta/credit-risk-analysis)
#
# ## About Dataset
# The dataset contains complete loan data for all loans issued through the year
# 2007 - 2015, including the current loan status (Current, Late, Fully Paid, etc.)
# and latest payment information.
#
# This project consists of 6 parts:
# 1. Introduction
# 2. Data Cleaning and Preprocessing
# 3. Data visualization
# 4. Modeling
# 5. Inference
# 6. Conclusion

# %% [markdown]
# # 1. Introduction
# This dataset contains total of 8,55,969 records
# with 73 features including target variable.

# %% [markdown]
# ## Attribute description:

# %% [markdown]
# 1. **id:** A unique identifier or reference number for each entry in the dataset.
# 2. **member_id:** A unique identifier or reference number for each member or individual associated with the loan.
# 3. **loan_amnt:** The total amount of the loan applied for or approved.
# 4. **funded_amnt:** The actual amount of the loan that has been funded or disbursed to the borrower.
# 5. **funded_amnt_inv:** The amount of the loan that was funded by investors. In some cases, loans can be funded by multiple investors.
# 6. **term:** The term or duration of the loan, typically in months (e.g., 36 months or 60 months).
# 7. **int_rate:** The annual interest rate (in percentage) charged on the loan.
# 8. **installment:** The monthly payment amount that the borrower needs to make to repay the loan.
# 9. **grade:** A rating or grade assigned to the loan, often reflecting the borrower's creditworthiness.
# 10. **sub_grade:** A more specific rating or grade within the grade category, providing additional information about the loan's risk.
# 11. **emp_title:** The job title or occupation of the borrower.
# 12. **emp_length:** The length of time the borrower has been employed.
# 13. **home_ownership:** The type of home ownership (e.g., own, rent, mortgage) of the borrower.
# 14. **annual_inc:** The annual income of the borrower.
# 15. **verification_status:** The status of income verification for the borrower (e.g., verified, not verified).
# 16. **issue_d:** The date when the loan was issued or originated.
# 17. **pymnt_plan:** An indicator of whether the loan has a payment plan.
# 18. **desc:** A description or additional information related to the loan.
# 19. **purpose:** The purpose for which the loan is being used (e.g., debt consolidation, home improvement).
# 20. **title:** The title or description of the loan.
# 21. **zip_code:** The borrower's ZIP code.
# 22. **addr_state:** The state in which the borrower resides.
# 23. **dti:** Debt-to-Income ratio, representing the borrower's total debt payments as a percentage of their income.
# 24. **delinq_2yrs:** The number of times the borrower has been 30+ days past due on a payment in the last two years.
# 25. **earliest_cr_line:** The date when the borrower's earliest credit line was opened.
# 26. **inq_last_6mths:** The number of credit inquiries in the last six months.
# 27. **mths_since_last_delinq:** The number of months since the borrower's last delinquency(failed to pay the scheduled payment).
# 28. **mths_since_last_record:** The number of months since the last public record (e.g., bankruptcy, tax lien).
# 29. **open_acc:** The number of open credit lines or accounts.
# 30. **pub_rec:** The number of derogatory public records on the borrower's credit report.
# 31. **revol_bal:** The total revolving balance (credit card balance) of the borrower.
# 32. **revol_util:** The revolving utilization rate, representing the percentage of available credit being used.
# 33. **total_acc:** The total number of credit lines or accounts on the borrower's credit report.
# 34. **initial_list_status:** The initial listing status of the loan (e.g., whole or fractional).
# 35. **out_prncp:** The outstanding principal balance of the loan.
# 36. **out_prncp_inv:** The outstanding principal balance of the loan funded by investors.
# 37. **total_pymnt:** The total amount paid by the borrower.
# 38. **total_pymnt_inv:** The total amount paid by investors.
# 39. **total_rec_prncp:** The total amount of principal repaid.
# 40. **total_rec_int:** The total amount of interest paid.
# 41. **total_rec_late_fee:** The total amount of late fees paid.
# 42. **recoveries:** The amount recovered in case of loan default.
# 43. **collection_recovery_fee:** A fee associated with the collection of a defaulted loan.
# 44. **last_pymnt_d:** The date of the last payment received.
# 45. **last_pymnt_amnt:** The amount of the last payment received.
# 46. **next_pymnt_d:** The date of the next scheduled payment.
# 47. **last_credit_pull_d:** The date when the borrower's credit report was last pulled.
# 48. **collections_12_mths_ex_med:** The number of collections in the last 12 months excluding medical collections.
# 49. **mths_since_last_major_derog:** The number of months since the last major derogatory event.
# 50. **policy_code:** A code indicating the lending policy in effect at the time of the loan.
# 51. **application_type:** The type of application (e.g., individual or joint).
# 52. **annual_inc_joint:** The annual income of joint applicants (if applicable).
# 53. **dti_joint:** The Debt-to-Income ratio for joint applicants (if applicable).
# 54. **verification_status_joint:** The status of income verification for joint applicants (if applicable).
# 55. **acc_now_delinq:** The number of accounts on which the borrower is currently delinquent.
# 56. **tot_coll_amt:** The total collection amounts ever owed.
# 57. **tot_cur_bal:** The total current balance of all current credit lines.
# 58. **open_acc_6m:** The number of open credit lines in the last 6 months.
# 59. **open_il_6m:** The number of currently open installment accounts in the last 6 months.
# 60. **open_il_12m:** The number of installment accounts opened in the last 12 months.
# 61. **open_il_24m:** The number of installment accounts opened in the last 24 months.
# 62. **mths_since_rcnt_il:** The months since the most recent installment account opened.
# 63. **total_bal_il:** The total balance of all installment accounts.
# 64. **il_util:** The ratio of total current balance to the high credit/credit limit on all installments.
# 65. **open_rv_12m:** The number of revolving accounts opened in the last 12 months.
# 66. **open_rv_24m:** The number of revolving accounts opened in the last 24 months.
# 67. **max_bal_bc:** The maximum balance on a revolving account in the last 12 months.
# 68. **all_util:** The balance-to-limit ratio on all trades.
# 69. **total_rev_hi_lim:** The total revolving high credit/credit limit.
# 70. **inq_fi:** The number of personal finance-related inquiries.
# 71. **total_cu_tl:** The number of finance trades.
# 72. **inq_last_12m:** The number of credit inquiries in the last 12 months.
# 73. **default_ind:** A binary indicator (0 or 1) to indicate loan default (1) or non-default (0).

# %% [markdown]
# ## **Let's look at the dataset**

# %%
# import required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("drive/My Drive/data.csv")
# df = pd.read_csv("drive/My Drive/Colab Notebooks/data/data.csv")
# df = pd.read_csv("data.csv")
# Out:
# <ipython-input-12-597fbd7a31eb>:1: DtypeWarning: Columns (17,45,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("drive/My Drive/data.csv")

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... il_util open_rv_12m open_rv_24m  \
# 0     10.65       162.87     B        B2  ...     NaN         NaN         NaN
# 1     15.27        59.83     C        C4  ...     NaN         NaN         NaN
# 2     15.96        84.33     C        C5  ...     NaN         NaN         NaN
# 3     13.49       339.31     C        C1  ...     NaN         NaN         NaN
# 4     12.69        67.79     B        B5  ...     NaN         NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           855969 non-null  int64
#  1   member_id                    855969 non-null  int64
#  2   loan_amnt                    855969 non-null  int64
#  3   funded_amnt                  855969 non-null  int64
#  4   funded_amnt_inv              855969 non-null  float64
#  5   term                         855969 non-null  object
#  6   int_rate                     855969 non-null  float64
#  7   installment                  855969 non-null  float64
#  8   grade                        855969 non-null  object
#  9   sub_grade                    855969 non-null  object
#  10  emp_title                    806526 non-null  object
#  11  emp_length                   812908 non-null  object
# ...

# %%
df.shape
# Out:
# (855969, 73)

# %%
features = df.columns.tolist()
features
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'pymnt_plan',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
# ...

# %%
pd.set_option('display.max_rows', None) # display all 73 rows
df.isna().sum()
# Out:
# id                                  0
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       49443
# emp_length                      43061
# home_ownership                      0
# annual_inc                          0
# verification_status                 0
# issue_d                             0
# pymnt_plan                          0
# desc                           734157
# purpose                             0
# title                              33
# zip_code                            0
# addr_state                          0
# dti                                 0
# delinq_2yrs                         0
# earliest_cr_line                    0
# ...

# %% [markdown]
# # 2. Data Cleaning

# %%
# Calculate the percentage of NaN values for each feature
nan_percentage = (df.isna().mean() * 100).round(2)

# Calculate the percentage of non-NaN values for each feature
non_nan_percentage = 100 - nan_percentage

# Create a DataFrame to display the results
nan_info_df = pd.DataFrame({'Feature': nan_percentage.index, 'NaN Percentage': nan_percentage.values, 'Non-NaN Percentage': non_nan_percentage.values})

# Sort the DataFrame by NaN Percentage in descending order
nan_info_df = nan_info_df.sort_values(by='NaN Percentage', ascending=False)

# Display the table
print(nan_info_df)
# Out:
#                         Feature  NaN Percentage  Non-NaN Percentage
# 51             annual_inc_joint           99.95                0.05
# 52                    dti_joint           99.95                0.05
# 53    verification_status_joint           99.95                0.05
# 63                      il_util           98.64                1.36
# 61           mths_since_rcnt_il           98.49                1.51
# 57                  open_acc_6m           98.45                1.55
# 58                   open_il_6m           98.45                1.55
# 60                  open_il_24m           98.45                1.55
# 62                 total_bal_il           98.45                1.55
# 59                  open_il_12m           98.45                1.55
# 71                 inq_last_12m           98.45                1.55
# 64                  open_rv_12m           98.45                1.55
# 65                  open_rv_24m           98.45                1.55
# ...

# %% [markdown]
# As it is visible, there are some columns having around 75 - 100% of the value filled with NaN. We can impute them with remaining other values if and only if the remaining data represents majority of the datasets imputing them with remaining 25% of the dataset might give false representation.

# %%
null_feature_list = ['annual_inc_joint', 'dti_joint', 'verification_status_joint', 'il_util', 'mths_since_rcnt_il', 'open_acc_6m', 'open_il_6m', 'mths_since_last_major_derog',
                     'open_il_24m', 'total_bal_il', 'open_il_12m', 'inq_last_12m', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl',
                     'desc', 'mths_since_last_record', 'mths_since_last_delinq']

# %%
df.drop(null_feature_list, axis=1, inplace=True)

# %% [markdown]
# Filling the null values(NaN) in the next_pymnt_d using the knowledge of the filled cells.

# %%
# dropping rows where last payment date is Null
df.dropna(subset=['last_pymnt_d'], inplace=True)

# %%
# Convert date columns to datetime objects
date_format = '%d-%m-%Y'
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], format=date_format)
df['next_pymnt_d'] = pd.to_datetime(df['next_pymnt_d'], format=date_format)

# Calculate the differences for rows with non-null next_pymnt_d
df['payment_diff'] = (df['next_pymnt_d'] - df['last_pymnt_d']).dt.days

# Calculate the mean difference
median_diff = df['payment_diff'].median()

# Fill null values in next_pymnt_d based on the scheme
df.loc[df['next_pymnt_d'].isnull(), 'next_pymnt_d'] = df['last_pymnt_d'] + pd.to_timedelta(median_diff, unit='D')

# Drop the temporary 'payment_diff' column if needed
df.drop(columns=['payment_diff'], inplace=True)

# %%
pd.set_option('display.max_rows', None) # display all features
df.isna().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                     48856
# emp_length                    42483
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# pymnt_plan                        0
# purpose                           0
# title                            27
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# earliest_cr_line                  0
# inq_last_6mths                    0
# open_acc                          0
# ...

# %% [markdown]
# #Data Visualization

# %%
df.shape
# Out:
# (847107, 52)

# %%
df['purpose'].value_counts()
# Out:
# debt_consolidation    500414
# credit_card           197975
# home_improvement       49471
# other                  40420
# major_purchase         16381
# small_business          9664
# car                     8517
# medical                 8066
# moving                  5104
# vacation                4489
# house                   3470
# wedding                 2268
# renewable_energy         545
# educational              323
# Name: purpose, dtype: int64

# %%
df['home_ownership'].value_counts()
# Out:
# MORTGAGE    424930
# RENT        338845
# OWN          83141
# OTHER          144
# NONE            45
# ANY              2
# Name: home_ownership, dtype: int64

# %%
fig, ax = plt.subplots(3,1, figsize = (20,20))
sns.countplot(y = df['purpose'], ax = ax[0]).set_xlabel('Borrower\'s Count')
ax[0].set_title("Count of Borrower's Purpose")
sns.countplot(y = df['home_ownership'], ax = ax[1]).set_xlabel('Borrower\'s Count')
ax[1].set_title("Count of Borrower's Home Ownership status")
sns.countplot(y = df['grade'], ax = ax[2]).set_xlabel('Borrower\'s Count')
ax[2].set_title("Count of Borrower's Grade")
fig.show()

# %% [markdown]
# Most borrowers have taken loan for debt consolidation, credit card and home
# improvement.Debt consolidation can simplify repayments and potentially offer lower interest rates.Some borrowers are managing their short-term financial needs through credit cards.
#
#
# Majority of borrowers have home_ownership status as rent and mortgage. Few of them own their house.
#
#
# Most borrowers have loan rating as B and C. Grades B and C typically indicate a range where borrowers may have a satisfactory but not excellent creditworthiness.

# %%
fig, ax = plt.subplots(1,3, figsize=(20,5))
ax = ax.ravel()

is_verified = df['verification_status'].value_counts()
piec_colors = sns.color_palette('pastel')[0:len(is_verified)]
is_verified.plot(kind = 'pie', colors=piec_colors, autopct='%1.2f%%', ax = ax[0])

term_list = df['term'].value_counts()
piec_colors = sns.color_palette('pastel')[0:len(term_list)]
term_list.plot(kind = 'pie', colors=piec_colors, autopct='%1.2f%%', ax = ax[1])

default_list = df['default_ind'].value_counts()
piec_colors = sns.color_palette('pastel')[0:len(default_list)]
default_list.plot(kind = 'pie', colors=piec_colors, autopct='%1.2f%%', ax = ax[2])
fig.show()

# %% [markdown]
# One-third of borrowers income is not verified. This could be due to various reasons such as self-employment, irregular income, or difficulties in obtaining employment verification documents.
#
# Most borrowers have opted for short term loans, i.e, 36 months. Lenders may encourage or prefer shorter-term loans to mitigate their risk exposure. Opting for a shorter-term loan could mean higher monthly payments but also a quicker payoff, allowing borrowers to free up their budgets sooner.
#
# Only 5% borrowers having default means stable economic conditions and reflects positively on the lender's ability to evaluate credit risk and make sound lending decisions.

# %%
# df['addr_state'].value_counts() returns a Series
state_counts = df['addr_state'].value_counts().reset_index()

# Rename the columns to make it more descriptive
state_counts.columns = ['state', 'borrower_count']

# Now state_counts is a DataFrame with columns 'state' and 'borrower_count'
print(state_counts)
# Out:
#    state  borrower_count
# 0     CA          123895
# 1     NY           70410
# 2     TX           67974
# 3     FL           58043
# 4     IL           34035
# 5     NJ           31742
# 6     PA           29918
# 7     OH           28347
# 8     GA           27731
# 9     VA           24954
# 10    NC           23545
# 11    MI           21934
# 12    MD           20016
# 13    MA           19646
# 14    AZ           19488
# 15    WA           18638
# 16    CO           18040
# 17    MN           15269
# 18    MO           13598
# 19    IN           13198
# 20    CT           12913
# 21    TN           12256
# 22    NV           11828
# 23    WI           11072
# 24    AL           10629
# 25    OR           10467
# 26    SC           10203
# 27    LA           10082
# 28    KY            8214
# 29    OK            7671
# 30    KS            7617
# 31    AR            6334
# 32    UT            6003
# 33    NM            4699
# 34    HI            4334
# 35    WV            4216
# ...

# %%
import plotly.express as px
fig = px.choropleth(state_counts,
                    locations='state',
                    locationmode="USA-states",
                    scope="usa",
                    color='borrower_count',
                    color_continuous_scale="Viridis_r",
                    )

fig.update_layout(
      title_text = 'Number of Borrowers in US state',
      title_font_family="Times New Roman",
      title_font_size = 32,
      title_font_color="black",
      title_x=0.5,
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Majority Borrowers are from California, New York, Texas and Florida. The concentration of borrowers in these states could be influenced by higher population density and increased economic activity. Borrowers from economically stable regions may have greater confidence in their ability to repay loans.

# %%
df['annual_inc'].median()
# Out:
# 65000.0

# %%
income_range = [0,25000,50000,75000,100000,150000,200000,500000,1000000]
income_df = df['annual_inc'].value_counts(bins=income_range,sort=False).reset_index()
income_df.columns = ['Range', 'borrower_count']
income_df['Range']= income_df['Range'].astype('string')

# %%
loan_range = [0,5000,10000,15000,20000,25000,30000,35000]
loan_df = df['loan_amnt'].value_counts(bins=loan_range,sort=False).reset_index()
loan_df.columns = ['Range', 'borrower_count']
loan_df['Range']= loan_df['Range'].astype('string')

# %%
dti_range = [0,5,10,15,20,25,30,50,100]
dti_df = df['dti'].value_counts(bins=dti_range,sort=False).reset_index()
dti_df.columns = ['Range', 'borrower_count']
dti_df['Range']= dti_df['Range'].astype('string')

# %%
fig, ax = plt.subplots(3,1, figsize=(20,25))
ax = ax.ravel()

ax[0].bar(income_df['Range'], income_df['borrower_count'], color='skyblue')
ax[0].set_xlabel('Annual Income Range(in $)')
ax[0].set_ylabel('Number of Borrowers')
ax[0].set_title('Number of Borrowers in Different Income Ranges')

ax[1].bar(loan_df['Range'], loan_df['borrower_count'], color='skyblue')
ax[1].set_xlabel('Loan Amount Range')
ax[1].set_ylabel('Number of Borrowers')
ax[1].set_title('Number of Borrowers in Different Loan Ranges')

ax[2].bar(dti_df['Range'], dti_df['borrower_count'], color='skyblue')
ax[2].set_xlabel('Debt to income ratio(in percentage)')
ax[2].set_ylabel('Number of Borrowers')
ax[2].set_title('Number of Borrowers in Different DTI Ranges')

fig.show()

# %% [markdown]
# The median income of borrower is $65k which suggests a moderate income level within the borrower population. As the income increases, the count of borrowers decreases. Less borrowers in income range 0-25k suggests lender avoid giving loan due to high credit risk.
#
# Amount of loan taken is mostly between 5k-15k. This may indicate addressing immediate expenses or making moderate-sized investments. From a lender's perspective, smaller loan amounts may be perceived as lower risk.
#
# Borrowers with a debt-to-income ratio in the range of 15-20% could indicate a balanced approach to managing debt obligations. They are likely mindful of not overcommitting their income to debt repayment, leaving room for other financial priorities. From a lender's perspective, borrowers with a debt-to-income ratio in the 15-20% range may represent a lower risk profile.

# %%
def extract_year(s):
    result = ''.join(char for char in s if char.isdigit())
    return int(result) if result else 0

# %%
df['emp_length'] = df['emp_length'].astype(str)
df['employment_years'] = df['emp_length'].apply(extract_year)

# %%
fig, ax = plt.subplots(2,2, figsize=(20,10))
ax = ax.ravel()

sns.kdeplot(x=df['int_rate'], ax=ax[0], fill=True)
ax[0].set_xlabel("Distribution of Interest Rate")
sns.kdeplot(x=df['installment'], ax=ax[1], fill=True)
ax[1].set_xlabel("Distribution of Installment Amount")
sns.kdeplot(x=df['total_rec_int'], ax=ax[2], fill=True)
ax[2].set_xlabel("Distribution of Paid Interest Amount")
sns.kdeplot(x=df['employment_years'], ax=ax[3], fill=True)
ax[3].set_xlabel("Distribution of Borrower's employement length")
# Out:
# Text(0.5, 0, "Distribution of Borrower's employement length")

# %% [markdown]
# Interest rate is mostly between 10-15%. Lenders often use risk-based pricing, where the interest rate is influenced by the borrower's creditworthiness. Borrowers with rates in this range may have credit profiles that place them in a moderate risk category.
#
# Monthly installment amount mostly ranges between $200-500.
#
# Interest amount paid peaks around $2000.
#
# Most of the borrowers have employment length greater than 10 years. Borrowers with employment lengths exceeding 10 years may be perceived as having stable and secure employment. Lenders may view such borrowers favorably, considering their long-term commitment to their current job.

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# * We can impute such columns where we have majority of known data.
# * Imputing the missing values in 'tot_coll_bal', 'tot_cur_bal', 'revol_util' and
# 'total_rev_hi_lim' with the median of the filled cells, of its respective columns.

# %%
# import imputer
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median')

# %%
# tot_coll_bal
tot_coll_amt = df['tot_coll_amt'].values.reshape(-1,1)
tot_coll_amt_imputed = imputer.fit_transform(tot_coll_amt)
df['tot_coll_amt'] = tot_coll_amt_imputed

# tot_cur_bal
tot_cur_bal = df['tot_cur_bal'].values.reshape(-1,1)
tot_cur_bal_imputed = imputer.fit_transform(tot_cur_bal)
df['tot_cur_bal'] = tot_cur_bal_imputed

# revol_util
revol_util = df['revol_util'].values.reshape(-1,1)
revol_util_imputed = imputer.fit_transform(revol_util)
df['revol_util'] = revol_util_imputed

# total_rev_hi_lim
total_rev_hi_lim = df['total_rev_hi_lim'].values.reshape(-1,1)
total_rev_hi_lim_imputed = imputer.fit_transform(total_rev_hi_lim)
df['total_rev_hi_lim'] = total_rev_hi_lim_imputed

# %% [markdown]
# removing instances having JOINT loan type in 'application_type', since there is no significant data available for JOINT loans.

# %%
df = df[df['application_type'] == 'INDIVIDUAL']

# %%
df.dropna(inplace=True)

# %%
pd.set_option('display.max_rows', None) # display all featues
df.isna().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                     0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# pymnt_plan                    0
# purpose                       0
# title                         0
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# ...

# %%
df.shape
# Out:
# (797814, 53)

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))

credit = df['home_ownership'].value_counts()
print(credit)
piec_colors = sns.color_palette('pastel')[0:len(credit)]
credit.plot(kind = 'pie', colors=piec_colors, autopct='%1.2f%%', ax=ax)

fig.show()
# Out:
# MORTGAGE    401594
# RENT        321763
# OWN          74275
# OTHER          138
# NONE            42
# ANY              2
# Name: home_ownership, dtype: int64

# %% [markdown]
# we can see that home ownership is categorical column with values as:
# * Rent
# * Own
# * Any
# * Mortgage
# * other
# * None
#
# We can remove instance of home ownership with type "Any" as it can be any of the type shown above.

# %%
df = df[df['home_ownership'] != "ANY"]

# %%
credit = df['home_ownership'].value_counts()
print(credit)
# Out:
# MORTGAGE    401594
# RENT        321763
# OWN          74275
# OTHER          138
# NONE            42
# Name: home_ownership, dtype: int64

# %%
# lets encode them into 5 categories
encoder =  LabelEncoder()

df['home_ownership'] = encoder.fit_transform(df['home_ownership'])
df['home_ownership'] += 1

# %%
print(df['home_ownership'][13:23])
# Out:
# 16    5
# 17    1
# 18    1
# 19    5
# 20    5
# 21    5
# 22    4
# 23    5
# 24    5
# 25    1
# Name: home_ownership, dtype: int64

# %% [markdown]
# we have grades as well as sub grades as our column thus we can keep subgrades which is superset of grades and drop grades column following by converting sub grades into its meaningful ranking.

# %%
df = df.drop(columns = ['grade'])

# %%
grades = set()
for index , val in enumerate(df['sub_grade']):
  grades.add(val)

# %%
grades = list(grades)
print(grades)
# Out:
# ['G1', 'G5', 'D2', 'F4', 'C3', 'A3', 'C2', 'C4', 'D4', 'C1', 'B1', 'G4', 'D1', 'B4', 'C5', 'E2', 'F2', 'D5', 'F3', 'A4', 'G3', 'E4', 'B3', 'B5', 'A2', 'B2', 'G2', 'E5', 'D3', 'E3', 'F1', 'E1', 'A1', 'A5', 'F5']

# %%
# sorting the grades
grades = sorted(grades)
print(grades)

# reversing the grades as A1 means highest grades thus should get higher value
grades.reverse()
print(grades)
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']
# ['G5', 'G4', 'G3', 'G2', 'G1', 'F5', 'F4', 'F3', 'F2', 'F1', 'E5', 'E4', 'E3', 'E2', 'E1', 'D5', 'D4', 'D3', 'D2', 'D1', 'C5', 'C4', 'C3', 'C2', 'C1', 'B5', 'B4', 'B3', 'B2', 'B1', 'A5', 'A4', 'A3', 'A2', 'A1']

# %%
# encoding grades on the basis of their ranking
grades_encoder = LabelEncoder()

grades_encoder.fit(grades)
df['sub_grade'] = grades_encoder.transform(df['sub_grade'])

# incrementing each value by 1 since base value of labelencoder is 0 and when multiplied by its weight it will always result as 0
df['sub_grade'] += 1

# %%
# encoding employment lengths
employment_lengths = ['< 1 year', '1 year', '2 years', '3 years', '4 years', '5 years', '6 years', '7 years', '8 years', '9 years', '10+ years', 'nan']

lengthencoder = LabelEncoder()
lengthencoder.fit(employment_lengths)

df['emp_length'] = lengthencoder.transform(df['emp_length'])

# %%
le = LabelEncoder()

# encoding other columns
encoding_list = ['term' , 'verification_status' , 'pymnt_plan' , 'application_type' , 'initial_list_status', 'purpose']
df[encoding_list] = df[encoding_list].apply(lambda col: le.fit_transform(col) + 1)

# %%
df.head(6)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 1  1077430    1314167       2500         2500           2500.0     2
# 3  1076863    1277178      10000        10000          10000.0     1
# 4  1075358    1311748       3000         3000           3000.0     2
# 5  1075269    1311441       5000         5000           5000.0     1
# 6  1069639    1304742       7000         7000           7000.0     2
# 7  1072053    1288686       3000         3000           3000.0     1
#
#    int_rate  installment  sub_grade                  emp_title  ...  \
# 1     15.27        59.83         14                      Ryder  ...
# 3     13.49       339.31         11        AIR RESOURCES BOARD  ...
# 4     12.69        67.79         10   University Medical Group  ...
# 5      7.90       156.46          4       Veolia Transportaton  ...
# 6     15.96       170.08         15  Southern Star Photography  ...
# 7     18.64       109.43         21            MKC Accounting   ...
#
# ...

# %% [markdown]
# * we need to find the time for which credit was issued.
# * From the attributes defination 25 and 47 which is first date when borrower's credit line was issued and last date when borrower's credit line was reviewed by the lender for further decision.
# * we can find the length by finding the difference between those two dates and further making new column of difference.

# %%
date_format = "%d-%m-%Y"
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], format=date_format)
df['last_credit_pull_d'] = pd.to_datetime(df['last_credit_pull_d'], format=date_format)

df['credit_history_duration'] = (df['last_credit_pull_d'] - df['earliest_cr_line']).dt.days

# %%
df.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 1  1077430    1314167       2500         2500           2500.0     2
# 3  1076863    1277178      10000        10000          10000.0     1
# 4  1075358    1311748       3000         3000           3000.0     2
# 5  1075269    1311441       5000         5000           5000.0     1
# 6  1069639    1304742       7000         7000           7000.0     2
#
#    int_rate  installment  sub_grade                  emp_title  ...  \
# 1     15.27        59.83         14                      Ryder  ...
# 3     13.49       339.31         11        AIR RESOURCES BOARD  ...
# 4     12.69        67.79         10   University Medical Group  ...
# 5      7.90       156.46          4       Veolia Transportaton  ...
# 6     15.96       170.08         15  Southern Star Photography  ...
#
#    collections_12_mths_ex_med  policy_code  application_type  acc_now_delinq  \
# ...

# %% [markdown]
# removing column which does not make sense in our classification analysis such as 'id' , 'member_id' etc

# %%
'''
null_feature_list = ['annual_inc_joint', 'dti_joint', 'verification_status_joint', 'il_util', 'mths_since_rcnt_il', 'open_acc_6m', 'open_il_6m', 'mths_since_last_major_derog',
                     'open_il_24m', 'total_bal_il', 'open_il_12m', 'inq_last_12m', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl',
                     'desc', 'mths_since_last_record', 'mths_since_last_delinq']
'''

dropnew = ['policy_code', 'id', 'member_id', 'emp_title', 'issue_d', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d',
           'last_credit_pull_d', 'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal']

# %%
df.drop(dropnew, axis=1, inplace=True)

# %%
df.shape
# Out:
# (797812, 37)

# %% [markdown]
# ### Feature selection

# %% [markdown]
# * we will plot a heatmap of out dataframe to see the correlation between different feature.
# * We can drop those feature with high correlation to avoid the data redundancy.

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr() , lw = 1 , cmap="crest")
# Out:
# <Axes: >

# %% [markdown]
# * we can see that there is high correlation between { total_payment_inv , total_pymnt , total_rec_prncp , installment}
# * similarly between {loan_amnt , funded_amnt , funded_amnt_inv}
# * same for {sub_grade , int_rate}

# %% [markdown]
# Thus we can keep one of them and drop rest to reduce the redundancy in feature which ultimately reduces overfitting of dataset.

# %%
redundancy = ["total_pymnt_inv" , "total_pymnt" , "total_rec_prncp" , "funded_amnt", "funded_amnt_inv"]

df.drop(redundancy , axis =  1 , inplace = True)

# %%
df.shape
# Out:
# (797812, 32)

# %% [markdown]
# we are now left with 30 columns and 797436 instances to work with.

# %% [markdown]
# ## Outliers detection

# %%
feature_list = df.columns.to_list() # List of remaining features

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    loan_amnt  term  int_rate  installment  sub_grade  emp_length  \
# 1       2500     2     15.27        59.83         14          10
# 3      10000     1     13.49       339.31         11           1
# 4       3000     2     12.69        67.79         10           0
# 5       5000     1      7.90       156.46          4           3
# 6       7000     2     15.96       170.08         15           8
#
#    home_ownership  annual_inc  verification_status  pymnt_plan  purpose  \
# 1               5     30000.0                    2           1        1
# 3               5     49200.0                    2           1       10
# 4               5     80000.0                    2           1       10
# 5               5     36000.0                    2           1       14
# 6               5     47004.0                    1           1        3
#
#      dti  delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# 1   1.00            0               5         3        0       1687
# ...

# %%
# Calculate the number of subplots based on the number of features
n_features = len(feature_list)

# Calculate the number of rows and columns for subplots
n_rows = (n_features + 1) // 2
n_cols = 2

# Create subplots
fig, ax = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))

# Flatten the 2D axis into 1D
ax = ax.ravel()

sns.set_theme(style="whitegrid")
for axid, col in enumerate(feature_list):
    sns.boxplot(x=df[col], ax=ax[axid])

# %% [markdown]
# As it is visible that, there are certain outliers in many features. Below is the list of feature containing outliers.

# %%
quantile_remove_list = ['int_rate', 'installment', 'sub_grade', 'annual_inc', 'pymnt_plan', 'purpose', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
                        'pub_rec', 'revol_bal', 'revol_util','total_acc','out_prncp', 'out_prncp_inv', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'acc_now_delinq', 'total_rev_hi_lim', 'credit_history_duration']

# %%
for col in quantile_remove_list:
    Q1 = np.percentile(df[col], 25, method='midpoint')
    Q3 = np.percentile(df[col], 75, method='midpoint')
    IRQ = Q3 - Q1
    upper_range = Q3 + 1.5 * IRQ
    lower_range = Q1 - 1.5 * IRQ

    outliers = df[(df[col] < lower_range) | (df[col] > upper_range)]
    df = df.loc[(df['default_ind'] == 1) | ~df.index.isin(outliers.index)]

# %% [markdown]
# feature selection list
# target
# dependent(x),independent(y) features on target

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[feature_list]
X.drop("default_ind", axis=1, inplace=True)
y = df["default_ind"]

# %%
X = X.values
y = y.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=21)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((200001, 31), (50001, 31))

# %% [markdown]
# ### Function to calculate errors

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

def calculateError(X_train_scaled, y_train, y_train_predicted, X_test_scaled, y_test, y_predicted):
    # Error in training data
    train_rmse = np.sqrt(mean_squared_error(list(y_train), y_train_predicted))
    train_mae = mean_absolute_error(list(y_train), y_train_predicted)

    print("Training root mean sqaure error is " , train_rmse)
    print("Training mean absolute error is " , train_mae)

    # Error in testing data
    test_rmse = np.sqrt(mean_squared_error(list(y_test), y_predicted))
    test_mae = mean_absolute_error(list(y_test), y_predicted)

    print("Test root mean sqaure error is " , test_rmse)
    print("Test mean absolute error is " , test_mae)

    return train_rmse, train_mae, test_rmse, test_mae

# %% [markdown]
# ### Function to calculate Model score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

def calculateScore(y_test, y_predicted, model):
  precision = 0
  if model == 'KNN':
    precision = precision_score(y_test, y_predicted, zero_division=1)
  else:
    precision = precision_score(y_test, y_predicted)
  accuracy = accuracy_score(y_test, y_predicted)
  recall = recall_score(y_test, y_predicted)
  f1 = f1_score(y_test, y_predicted)

  print('Precision: %.3f' % precision)
  print('Recall: %.3f' % recall)
  print('Accuracy: %.3f' % accuracy)
  print('F1 Score: %.3f' % f1)

  return precision, recall, accuracy, f1

# %% [markdown]
# ### Function to plot Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plotConfusion(y_test, y_predicted):
  conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_predicted)

  fig, ax = plt.subplots(figsize=(5, 5))
  ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
  for i in range(conf_matrix.shape[0]):
      for j in range(conf_matrix.shape[1]):
          ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

  plt.xlabel('Predictions', fontsize=18)
  plt.ylabel('Actuals', fontsize=18)
  plt.title('Confusion Matrix', fontsize=18)
  plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #4. Modeling

# %% [markdown]
# ### 1. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

randomForest = RandomForestClassifier(random_state = 21)
parameters = {'n_estimators': list(range(50, 60, 3)), 'max_depth': list(range(5, 15, 2)), 'max_features': ['sqrt', 'log2']}

RandomForest_Classifier = GridSearchCV(randomForest, parameters, n_jobs=20, verbose=0)
RandomForest_Classifier.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=21), n_jobs=20,
#              param_grid={'max_depth': [5, 7, 9, 11, 13],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 53, 56, 59]})

# %%
best_model = RandomForest_Classifier.best_estimator_

y_train_predicted = best_model.predict(X_train_scaled)
y_predicted = best_model.predict(X_test_scaled)

best_params_RF = RandomForest_Classifier.best_params_
print("Best parameters are " , best_params_RF)
# Out:
# Best parameters are  {'max_depth': 13, 'max_features': 'sqrt', 'n_estimators': 50}

# %%
# Calculate error
train_rmse_RF, train_mae_RF, test_rmse_RF, test_mae_RF = calculateError(X_train_scaled, y_train, y_train_predicted,
                                                                        X_test_scaled, y_test, y_predicted)
# Out:
# Training root mean sqaure error is  0.15532185736593265
# Training mean absolute error is  0.024124879375603123
# Test root mean sqaure error is  0.15773237590917027
# Test mean absolute error is  0.0248795024099518

# %%
# Calculate Score
precision_RF, recall_RF, accuracy_RF, f1_score_RF = calculateScore(y_test, y_predicted, 'RF')
# Out:
# Precision: 1.000
# Recall: 0.853
# Accuracy: 0.975
# F1 Score: 0.921

# %%
# Plot Confusion Matrix
plotConfusion(y_test, y_predicted)

# %% [markdown]
# ### 2. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression(random_state = 21)
parameters = {'max_iter': list(range(100, 201, 20))}

LogisticRegression_Classifier = GridSearchCV(LR, parameters, n_jobs=20, verbose=0)
LogisticRegression_Classifier.fit(X_train_scaled, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# GridSearchCV(estimator=LogisticRegression(random_state=21), n_jobs=20,
#              param_grid={'max_iter': [100, 120, 140, 160, 180, 200]})

# %%
best_model = LogisticRegression_Classifier.best_estimator_

y_train_predicted = best_model.predict(X_train_scaled)
y_predicted = best_model.predict(X_test_scaled)

best_params_LR = LogisticRegression_Classifier.best_params_
print("Best parameters are " , best_params_LR)
# Out:
# Best parameters are  {'max_iter': 160}

# %%
# Calculate error
train_rmse_LR, train_mae_LR, test_rmse_LR, test_mae_LR = calculateError(X_train_scaled, y_train, y_train_predicted,
                                                                        X_test_scaled, y_test, y_predicted)
# Out:
# Training root mean sqaure error is  0.21824243824515602
# Training mean absolute error is  0.04762976185119074
# Test root mean sqaure error is  0.2156364301749582
# Test mean absolute error is  0.046499070018599625

# %%
# Calculate Score
precision_LR, recall_LR, accuracy_LR, f1_score_LR = calculateScore(y_test, y_predicted, 'LR')
# Out:
# Precision: 0.973
# Recall: 0.747
# Accuracy: 0.954
# F1 Score: 0.845

# %%
# Plot Confusion Matrix
plotConfusion(y_test, y_predicted)

# %% [markdown]
# ### 3. KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier()
parameters = {'n_neighbors':list(range(15,31,2)), 'weights':['uniform', 'distance']}

KNN_classifier = GridSearchCV(KNN, parameters, n_jobs=20, verbose=0)
KNN_classifier.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=20,
#              param_grid={'n_neighbors': [15, 17, 19, 21, 23, 25, 27, 29],
#                          'weights': ['uniform', 'distance']})

# %%
best_model = KNN_classifier.best_estimator_

y_train_predicted = best_model.predict(X_train_scaled)
y_predicted = best_model.predict(X_test_scaled)

best_params_KNN = KNN_classifier.best_params_
print("Best parameters are " , best_params_KNN)
# Out:
# Best parameters are  {'n_neighbors': 25, 'weights': 'distance'}

# %%
# Calculate error
train_rmse_KNN, train_mae_KNN, test_rmse_KNN, test_mae_KNN = calculateError(X_train_scaled, y_train, y_train_predicted,
                                                                            X_test_scaled, y_test, y_predicted)
# Out:
# Training root mean sqaure error is  0.4120244545888558
# Training mean absolute error is  0.1697641511792441
# Test root mean sqaure error is  0.4120395666291171
# Test mean absolute error is  0.16977660446791065

# %%
# Calculate Score
precision_KNN, recall_KNN, accuracy_KNN, f1_score_KNN = calculateScore(y_test, y_predicted, 'KNN')
# Out:
# Precision: 1.000
# Recall: 0.000
# Accuracy: 0.830
# F1 Score: 0.000

# %%
# Plot Confusion Matrix
plotConfusion(y_test, y_predicted)

# %% [markdown]
# ###4. SVC

# %%
from sklearn.svm import SVC

svc = SVC()
parameters = {'degree': [2, 3, 4, 5], 'decision_function_shape': ['ovr', 'ovo'], 'kernal': ['linear', 'poly', 'rbf']}

svc = GridSearchCV(svc, parameters, n_jobs=20, verbose=0)
svc.fit(X_train, y_train)

# %%
best_model = SVC_classifier.best_estimator_

y_train_predicted = best_model.predict(X_train_scaled)
y_predicted = best_model.predict(X_test_scaled)

best_params_SVC = SVC_classifier.best_params_
print("Best parameters are " , best_params_SVC)

# %%
# Calculate error
train_rmse_SVC, train_mae_SVC, test_rmse_SVC, test_mae_SVC = calculateError(X_train_scaled, y_train, y_train_predicted,
                                                                            X_test_scaled, y_test, y_predicted)

# %%
# Calculate Score
precision_SVC, recall_SVC, accuracy_SVC, f1_score_SVC = calculateScore(y_test, y_predicted, 'SVC')

# %%
# Plot Confusion Matrix
plotConfusion(y_test, y_predicted)

# %% [markdown]
# ### Results

# %%
def eval_models():
  models = ['Random Forest Classifier', 'Logistic Regression', 'KNN Classifier','SVC Classifier']

  model_errors = pd.DataFrame()
  model_errors['Model Name'] = models
  model_errors['Train_RMSE'] = [train_rmse_RF, train_rmse_LR, train_rmse_KNN, train_rmse_SVC]
  model_errors['Test_RMSE'] = [test_rmse_RF, test_rmse_LR, test_rmse_KNN, test_rmse_SVC]
  model_errors['Train_MAE'] = [train_mae_RF, train_mae_LR, train_mae_KNN, train_mae_SVC]
  model_errors['Test_MAE'] = [test_mae_RF, test_mae_LR, test_mae_KNN, test_mae_SVC]

  best_params_model = pd.DataFrame()
  best_params_model['Model Name'] = models
  best_params_model['Best Parameters'] = [best_params_RF, best_params_LR, best_params_KNN, best_params_SVC]

  model_score = pd.DataFrame()
  model_score['Model Name'] = models
  model_score['Precision'] = [precision_RF, precision_LR, precision_KNN, precision_SVC]
  model_score['Recall'] = [recall_RF, recall_LR, recall_KNN, recall_SVC]
  model_score['Accuracy Score'] = [accuracy_RF, accuracy_LR, accuracy_KNN, accuracy_SVC]
  model_score['F1 Score'] = [f1_score_RF, f1_score_LR, f1_score_KNN, f1_score_SVC]

  return model_errors, best_params_model, model_score

# %%
model_errors, best_params_model, model_score = eval_models()

# %%
model_errors

# %%
best_params_model

# %%
model_score
